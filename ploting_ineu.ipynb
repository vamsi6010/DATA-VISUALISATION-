# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from numpy.random import randn, randint, uniform, sample

# %%
df = pd.DataFrame(randn(1000),index = pd.date_range('2019-06-07',periods = 1000), columns=['values'])
ts = pd.Series(randn(1000), index = pd.date_range('2019-06-07', periods = 1000))
df.head()
# Out:
#               values
# 2019-06-07  1.779528
# 2019-06-08  0.282820
# 2019-06-09  0.801075
# 2019-06-10  0.687454
# 2019-06-11  0.918423

# %%
ts.head()
# Out:
# 2019-06-07    0.303813
# 2019-06-08    0.004133
# 2019-06-09    0.661811
# 2019-06-10    0.152899
# 2019-06-11   -1.266593
# Freq: D, dtype: float64

# %%
#simple plot with out using any library
ts.plot(figsize=(5,5))

# %%
ts = ts.cumsum()
ts.head()
# Out:
# 2019-06-07    0.303813
# 2019-06-08    0.307946
# 2019-06-09    0.969757
# 2019-06-10    1.122656
# 2019-06-11   -0.143937
# Freq: D, dtype: float64

# %%
ts.plot(figsize = (10,5))

# %%
df.plot()

# %%
dd = df.cumsum()
dd.plot()

# %%
#iris is a dataset that is alredy available in seaborn library
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax = iris.plot(figsize=(15,8),title="iris data set ")
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
# Out:
# Text(0, 0.5, 'Y axis')

# %%
#x axis gives the index 
#y axis has the values

# %%
ts.plot(kind = 'bar')
#as it is trying to accomidte all values in tiny space its showing pressed

# %%
ts.plot(kind='bar', figsize=(10,10))

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
idf = iris.drop(columns=['species'])
#bcs species is a categorical data were droping it 
idf
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
#gives us the values at 0th index 
idf.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
idf.iloc[0].plot(kind='bar')

# %%
titan = sns.load_dataset('titanic')
titan
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
rdd = pd.DataFrame(randn(10,4),columns=['a','b','c','d'])
rdd
# Out:
#           a         b         c         d
# 0 -0.320555 -0.726068 -0.714581  0.006814
# 1  1.224237  1.097592 -0.399005 -0.807724
# 2  0.674490  0.413137  0.444493 -0.549805
# 3 -1.988957  0.273299  1.270505  0.110903
# 4 -0.423569 -0.052922  0.381228 -0.178393
# 5 -1.031371  0.187035 -0.064424 -0.328121
# 6 -0.215956 -0.163569  1.503405  1.301249
# 7  0.531361  0.752817  0.638301 -0.266356
# 8 -1.052240 -1.486203 -0.489745  1.068413
# 9 -1.039631  1.396350 -1.015164  0.726969

# %%
rdd.plot(kind='bar',figsize = (10,10))

# %%
rdd.plot.barh(figsize=(10,10))
#by using this we will plot the same bar but the axis are rotates from last one

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris['sepal_length'].plot.hist(figsize=(15,6))
#histogram showcases distribution in x-axis and magnitude in y axis
#data on the x-axis and its number of occurances on the y axis

# %%
iris.plot(kind='hist',figsize=(8,8))

# %%
iris.plot(kind='hist',stacked = True, bins= 50,figsize=(8,5))
#stacked is used wether we want to stack our data or not 
#higher the. bins lesser the width of the bars

# %%
iris.plot(kind='hist',stacked = True, bins= 50,figsize=(8,5),orientation='horizontal')
#same plot but axis got shifted

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind='hist',bins = 50)

# %%
 idf
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
idf.diff().hist(color = 'r',alpha=0.5,figsize = (5,5))
#alpha is the intensitu of the color
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x129cdb9a0>,
# ...
#       dtype=object)

# %%
#sctter plot
idf.plot.scatter(x='sepal_length',y='petal_length')
#this knd of plots is used to analysis the pattern of the data helps in machine learning

# %%
idf.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width')
#based on the values of x,y a point is plotted and the correspondig color of c is given

# %%
idf.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width',s=40)
#s is the size of the bubbles greater the s higher the diameter

# %%
#hexbin plot
idf.plot.hexbin(x='sepal_length',y='petal_length',gridsize=20)

# %%
#pie plot
p1 = idf.iloc[0]
p1.plot.pie(figsize=(6,6))
#pie chart is the percentage contribution of the data

# %%
p2 = idf.head(3).T
#t transposes the rows - columns and vice versa
p2
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
p2.plot.pie(subplots = True,figsize=(20,20),autopct='%.2f', fontsize = 24)
#autopct gives the percentage
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1263bec40>,
# ...
#       dtype=object)

# %%
#sctter matrices
#it draws scatter matrix for all the columns with all columns

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(idf,diagonal='kde',figsize=(8,8))
#diag shows wether ourr data is normalised or not
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12ee029d0>,
# ...
#       dtype=object)

# %%
#kde
#kernel density estimation 
#we can find wether our data is normalised or not
idf['sepal_length'].plot.kde()

# %%
ts.plot(style = 'r--', label = 'Series',legend = True)
#LEGEND TRUE SHOWS THE LABLE ON TOP RIGHT CORNOR R-- takes color red and plot will be plotted --

# %%
idf.plot(legend = True, figsize = (10, 5), logy = True)
#logy gives the log values of the data

# %%
idf.plot(subplots=True)
#it plots differetn graphs for diff columns
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x12f85ffa0>,
# ...
#       dtype=object)

# %%
idf.plot(subplots = True, sharex = False, layout = (2,3), figsize = (16,8))
#layout plots in 2 rows and 3 columns only 
plt.tight_layout()
